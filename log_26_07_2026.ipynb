# %%
import numpy as np
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![image.png](attachment:303e6bde-d30e-4ce4-ad99-44afea5df155.png)

# %% [markdown]
# ![image.png](attachment:b7de7a6f-ae98-4e11-b884-5d3dd35e21e3.png)

# %%
'''
In math, e is a famous number called Euler's number (pronounced "Oiler's number"). 
It is a constant—a fixed number like pi (π)—that is roughly equal to 2.71828
'''

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, 500)

# e = 2.718281828459045                                 --- or math.e
# b0 = -11.052
# b1 = 2.197
